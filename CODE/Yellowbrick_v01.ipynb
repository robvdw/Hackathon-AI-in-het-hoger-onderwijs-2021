# %%
import os
import sys

# Modify the path
sys.path.append("..")

import numpy as np
import pandas as pd
import yellowbrick as yb
import matplotlib.pyplot as plt
# %matplotlib notebook


g = yb.anscombe()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="800">
